# %%
# !pip install seqeval
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from seqeval) (2.0.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.11/dist-packages (from seqeval) (1.6.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=52e7074bd017cb501015d5f7c40b331f1083322ea5eb3e6177f5fb0b4f951de4
#   Stored in directory: /root/.cache/pip/wheels/bc/92/f0/243288f899c2eacdfa8c5f9aede4c71a9bad0ee26a01dc5ead
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
# !pip install pytorch-crf -i https://pypi.tuna.tsinghua.edu.cn/simple/
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Collecting pytorch-crf
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/96/7d/4c4688e26ea015fc118a0327e5726e6596836abce9182d3738be8ec2e32a/pytorch_crf-0.7.2-py3-none-any.whl (9.5 kB)
# Installing collected packages: pytorch-crf
# Successfully installed pytorch-crf-0.7.2

# %%
# Named Entity Recognition with SecBERT + BiLSTM + CRF
# Homework 3 - Bonus Implementation

import os
import re
import sys
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
from tqdm import tqdm
import seaborn as sns
from seqeval.metrics import classification_report as seq_classification_report
from seqeval.metrics import f1_score, precision_score, recall_score

# Set environment variables to help with CUDA debugging
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# Force CPU or GPU
FORCE_CPU = False  # Set to False to enable GPU

# Check and install required packages
required_packages = {
    'transformers': 'transformers',
    'torchcrf': 'pytorch-crf',
    'seqeval': 'seqeval',
}

# Check if necessary packages are installed
for module_name, package_name in required_packages.items():
    try:
        __import__(module_name)
    except ImportError:
        print(f"Package {module_name} is required. Please run:")
        print(f"pip install {package_name}")
        print("Then run this program again")
        sys.exit(1)

# Import necessary modules
from transformers import AutoModel, AutoTokenizer
from torchcrf import CRF

# Check if GPU is available
if FORCE_CPU:
    device = torch.device('cpu')
    print("Using CPU as specified")
else:
    try:
        if torch.cuda.is_available():
            # Test CUDA functionality
            test_tensor = torch.tensor([1.0]).cuda()
            test_tensor = test_tensor + 1.0
            device = torch.device('cuda')
            print(f"CUDA is available and working. Using device: {device}")
            print(f"CUDA Version: {torch.version.cuda}")
            print(f"GPU: {torch.cuda.get_device_name(0)}")
        else:
            device = torch.device('cpu')
            print(f"CUDA not available. Using device: {device}")
    except Exception as e:
        print(f"Error initializing CUDA: {e}")
        print("Falling back to CPU")
        device = torch.device('cpu')

# Set random seed for reproducibility
try:
    torch.manual_seed(42)
    if device.type == 'cuda':
        torch.cuda.manual_seed_all(42)
except Exception as e:
    print(f"Warning: Could not set CUDA random seed: {e}")

np.random.seed(42)

# Define dataset file paths
TRAIN_FILE = "train.txt"
VALID_FILE = "valid.txt"
TEST_FILE = "test.txt"

# Parameters
MAX_LEN = 128  # Maximum sequence length
BATCH_SIZE = 16
LEARNING_RATE = 2e-5
EPOCHS = 30
DROPOUT = 0.1
LSTM_HIDDEN_DIM = 768
LSTM_LAYERS = 2
WEIGHT_DECAY = 0.01

# Use SecBERT instead of standard BERT for cybersecurity domain
MODEL_NAME = "jackaduma/SecBERT"  # SecBERT is specialized for security domain

# Load tokenizer
print(f"Loading tokenizer for pretrained model '{MODEL_NAME}'...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
print("Tokenizer loaded successfully")

# Function to read CoNLL format NER data
def read_conll(file_path):
    """Read file in CoNLL format with special handling for malformed lines"""
    sentences = []
    labels = []

    sentence = []
    label = []

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line == "":
                if sentence:
                    sentences.append(sentence)
                    labels.append(label)
                    sentence = []
                    label = []
            else:
                # Split by whitespace
                parts = line.split()

                # Special handling for malformed lines
                if len(parts) == 1:
                    # This might be a line with just a tag (like 'O')
                    # Skip this line, don't show warning
                    continue
                elif len(parts) >= 2:
                    # Normal case: we have at least a token and a tag
                    word = parts[0]
                    tag = parts[-1]  # Last element is the tag
                    sentence.append(word)
                    label.append(tag)

        # Add the last sentence if the file doesn't end with an empty line
        if sentence:
            sentences.append(sentence)
            labels.append(label)

    # Print sample to verify format
    if sentences:
        print(f"Data format sample (from {file_path}):")
        for i, (token, tag) in enumerate(zip(sentences[0][:5], labels[0][:5])):
            print(f"  {token} -> {tag}")

    return sentences, labels

# Read datasets
print(f"Reading training set: {TRAIN_FILE}")
train_sentences, train_labels = read_conll(TRAIN_FILE)
print(f"Reading validation set: {VALID_FILE}")
valid_sentences, valid_labels = read_conll(VALID_FILE)
print(f"Reading test set: {TEST_FILE}")
test_sentences, test_labels = read_conll(TEST_FILE)

print(f"Training set: {len(train_sentences)} sentences")
print(f"Validation set: {len(valid_sentences)} sentences")
print(f"Test set: {len(test_sentences)} sentences")

# Display a sample from training data
print("\nSample from training data:")
for token, label in zip(train_sentences[0][:10], train_labels[0][:10]):
    print(f"{token} -> {label}")

# Get unique tags
unique_tags = sorted(list(set(tag for doc in train_labels for tag in doc)))
tag2idx = {tag: idx for idx, tag in enumerate(unique_tags)}
idx2tag = {idx: tag for idx, tag in enumerate(unique_tags)}

print(f"\nUnique tags: {unique_tags}")
print(f"Number of unique tags: {len(unique_tags)}")

# NER Dataset class
class NERDataset(Dataset):
    def __init__(self, sentences, labels, tokenizer, max_len, tag2idx):
        self.sentences = sentences
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.tag2idx = tag2idx

    def __len__(self):
        return len(self.sentences)

    def __getitem__(self, idx):
        sentence = self.sentences[idx]
        word_labels = self.labels[idx]

        # Tokenize the sentence
        encoding = self.tokenizer(
            sentence,
            is_split_into_words=True,
            return_offsets_mapping=True,
            padding='max_length',
            truncation=True,
            max_length=self.max_len,
            return_tensors='pt'
        )

        # Remove batch dimension added by tokenizer
        input_ids = encoding['input_ids'].squeeze(0)
        attention_mask = encoding['attention_mask'].squeeze(0)
        offsets = encoding['offset_mapping'].squeeze(0)

        # Create token labels aligned with BERT's WordPiece tokenization
        labels = torch.ones(input_ids.shape, dtype=torch.long) * -100  # -100 is ignored by PyTorch's CrossEntropyLoss

        # Map word tokens to word pieces (handle subword tokenization)
        word_ids = encoding.word_ids()
        previous_word_idx = None

        for i, word_idx in enumerate(word_ids):
            # Skip special tokens
            if word_idx is None:
                continue

            # Only label the first token of a word
            if word_idx != previous_word_idx:
                # If the word index is within our word_labels range
                if word_idx < len(word_labels):
                    labels[i] = self.tag2idx.get(word_labels[word_idx], 0)  # Default to 'O' (0) if tag not in tag2idx

            previous_word_idx = word_idx

        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'labels': labels
        }

# Create datasets
train_dataset = NERDataset(train_sentences, train_labels, tokenizer, MAX_LEN, tag2idx)
valid_dataset = NERDataset(valid_sentences, valid_labels, tokenizer, MAX_LEN, tag2idx)
test_dataset = NERDataset(test_sentences, test_labels, tokenizer, MAX_LEN, tag2idx)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# Define the improved SecBERT + BiLSTM + CRF model
class SecBERTBiLSTMCRF(nn.Module):
    def __init__(self, bert_model_name, num_tags, lstm_hidden_dim=768, lstm_layers=2, dropout=0.1):
        super(SecBERTBiLSTMCRF, self).__init__()

        # SecBERT layer
        self.bert = AutoModel.from_pretrained(bert_model_name)

        # BiLSTM layer with multiple layers for better feature extraction
        self.lstm = nn.LSTM(
            input_size=self.bert.config.hidden_size,
            hidden_size=lstm_hidden_dim // 2,  # Divide by 2 for bidirectional
            num_layers=lstm_layers,
            bidirectional=True,
            batch_first=True,
            dropout=dropout if lstm_layers > 1 else 0  # Apply dropout between LSTM layers
        )

        # Dropout
        self.dropout = nn.Dropout(dropout)

        # Linear layer for tag prediction
        self.hidden2tag = nn.Linear(lstm_hidden_dim, num_tags)

        # CRF layer for structured prediction
        self.crf = CRF(num_tags, batch_first=True)

    def forward(self, input_ids, attention_mask, labels=None):
        # Get SecBERT outputs
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        sequence_output = outputs.last_hidden_state

        # Apply BiLSTM
        lstm_output, _ = self.lstm(sequence_output)
        lstm_output = self.dropout(lstm_output)

        # Apply linear layer to get emissions for CRF
        emissions = self.hidden2tag(lstm_output)

        # If labels are provided, calculate loss, otherwise return emissions for prediction
        if labels is not None:
            # Create mask from attention_mask
            mask = attention_mask.bool()

            # Replace -100 labels with 0 (or any valid tag index) to avoid CRF errors
            # CRF will use the mask to ignore these positions
            labels_fixed = labels.clone()
            labels_fixed[labels == -100] = 0  # Replace with a valid tag index (0)

            # Calculate negative log likelihood loss for CRF
            log_likelihood = self.crf(emissions, labels_fixed, mask=mask, reduction='mean')
            return -log_likelihood
        else:
            # Decode the best path
            mask = attention_mask.bool()
            best_tags = self.crf.decode(emissions, mask=mask)
            return best_tags

# Initialize the model with error handling
try:
    print("Initializing model...")
    model = SecBERTBiLSTMCRF(MODEL_NAME, len(tag2idx), lstm_hidden_dim=LSTM_HIDDEN_DIM, lstm_layers=LSTM_LAYERS, dropout=DROPOUT)
    model.to(device)
    print(f"Model successfully initialized and moved to {device}")
except Exception as e:
    print(f"Error initializing model: {e}")
    raise

# Set up the optimizer with weight decay
print("Setting up optimizer...")
no_decay = ['bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
     'weight_decay': WEIGHT_DECAY},
    {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)],
     'weight_decay': 0.0}
]
optimizer = optim.AdamW(optimizer_grouped_parameters, lr=LEARNING_RATE)
print("Optimizer configured successfully")

# Training and evaluation functions
def train_epoch(model, dataloader, optimizer, device):
    model.train()
    total_loss = 0

    progress_bar = tqdm(dataloader, desc="Training")
    for batch in progress_bar:
        try:
            # Clear gradients
            optimizer.zero_grad()

            # Move batch to device
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            # Forward pass
            loss = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)

            # Backward pass
            loss.backward()

            # Gradient clipping to prevent exploding gradients
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

            # Update parameters
            optimizer.step()

            # Update total loss
            total_loss += loss.item()

            # Update progress bar
            progress_bar.set_postfix({"Loss": total_loss / (progress_bar.n + 1)})
        except Exception as e:
            print(f"Error in batch training: {e}")
            import traceback
            traceback.print_exc()
            continue

    return total_loss / len(dataloader)

def evaluate(model, dataloader, device, tag2idx, idx2tag):
    model.eval()

    predictions = []
    true_labels = []

    with torch.no_grad():
        for batch in tqdm(dataloader, desc="Evaluating"):
            try:
                # Move batch to device
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                labels = batch['labels'].to(device)

                # Get predictions
                best_paths = model(input_ids=input_ids, attention_mask=attention_mask)

                # Move to CPU for processing
                input_ids = input_ids.cpu().numpy()
                attention_mask = attention_mask.cpu().numpy()
                labels = labels.cpu().numpy()

                # Process each sequence in the batch
                for i, (path, label, mask) in enumerate(zip(best_paths, labels, attention_mask)):
                    pred_list = []
                    true_list = []

                    for j, m in enumerate(mask):
                        if m and label[j] != -100:  # Skip padding and subword tokens
                            if j < len(path):  # Make sure we don't go out of bounds
                                pred_tag = idx2tag.get(path[j], "O")  # Default to "O" if unknown
                                true_tag = idx2tag.get(label[j], "O")  # Default to "O" if unknown

                                pred_list.append(pred_tag)
                                true_list.append(true_tag)

                    predictions.append(pred_list)
                    true_labels.append(true_list)
            except Exception as e:
                print(f"Error in evaluation: {e}")
                import traceback
                traceback.print_exc()
                continue

    # Use seqeval for entity-level evaluation instead of token-level
    try:
        seq_report = seq_classification_report(true_labels, predictions, digits=4)
        seq_f1 = f1_score(true_labels, predictions)
        seq_p = precision_score(true_labels, predictions)
        seq_r = recall_score(true_labels, predictions)
        print(f"Entity-level metrics - F1: {seq_f1:.4f}, Precision: {seq_p:.4f}, Recall: {seq_r:.4f}")
    except Exception as e:
        print(f"Error generating seqeval report: {e}")
        seq_report = "Seqeval report generation failed"

    # Flatten the lists for token-level evaluation (handle empty lists)
    flat_preds = []
    flat_labels = []

    for sublist in predictions:
        flat_preds.extend(sublist)

    for sublist in true_labels:
        flat_labels.extend(sublist)

    # Make sure we have equal lengths
    min_len = min(len(flat_preds), len(flat_labels))
    flat_preds = flat_preds[:min_len]
    flat_labels = flat_labels[:min_len]

    # Calculate token-level metrics if we have predictions
    if len(flat_preds) > 0 and len(flat_labels) > 0:
        try:
            token_report = classification_report(flat_labels, flat_preds, digits=4)
        except Exception as e:
            print(f"Error generating token-level classification report: {e}")
            token_report = "Token-level classification report generation failed"
    else:
        token_report = "No valid predictions to evaluate"

    return seq_report, token_report, predictions, true_labels, seq_f1

# Define learning rate scheduler for better convergence
from torch.optim.lr_scheduler import ReduceLROnPlateau
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2, verbose=True)

# Early stopping parameters
PATIENCE = 3  # Number of epochs to wait for improvement before stopping
EARLY_STOPPING_DELTA = 0.001  # Minimum improvement to qualify as an improvement

# Train the model with error handling and early stopping
train_losses = []
val_f1s = []
val_reports = []
best_f1 = 0
best_model_state = None
patience_counter = 0  # Counter for early stopping

try:
    for epoch in range(EPOCHS):
        print(f"\n{'='*20} Epoch {epoch + 1}/{EPOCHS} {'='*20}")

        try:
            # Train
            print("Starting training phase...")
            train_loss = train_epoch(model, train_loader, optimizer, device)
            train_losses.append(train_loss)

            # Evaluate on validation set
            print("Starting validation phase...")
            val_report, token_report, _, _, val_f1 = evaluate(model, valid_loader, device, tag2idx, idx2tag)
            val_reports.append(val_report)
            val_f1s.append(val_f1)

            # Update learning rate based on validation F1
            scheduler.step(val_f1)

            # Early stopping logic
            if val_f1 - best_f1 > EARLY_STOPPING_DELTA:
                # We have an improvement
                best_f1 = val_f1
                best_model_state = model.state_dict().copy()
                patience_counter = 0  # Reset patience counter
                print(f"New best model saved with F1: {best_f1:.4f}")
            else:
                # No significant improvement
                patience_counter += 1
                print(f"No significant improvement. Patience: {patience_counter}/{PATIENCE}")

                if patience_counter >= PATIENCE:
                    print(f"Early stopping triggered after {epoch + 1} epochs!")
                    break

            print(f"Training Loss: {train_loss:.4f}, Validation F1: {val_f1:.4f}")
            print("Entity-Level Validation Report:")
            print(val_report)
            print("Token-Level Validation Report:")
            print(token_report)
            print("-" * 60)

        except Exception as e:
            print(f"Error during epoch {epoch + 1}: {e}")
            if epoch > 0:  # Only continue if we have at least one successful epoch
                print("Continuing to next epoch...")
                continue
            else:
                raise

    # Save the trained model
    if best_model_state is not None:
        print("Saving best model...")
        torch.save(best_model_state, "secbert_bilstm_crf_ner_model.pt")
        # Load best model for final evaluation
        model.load_state_dict(best_model_state)
    else:
        print("Saving final model...")
        torch.save(model.state_dict(), "secbert_bilstm_crf_ner_model.pt")

    print("Model saved!")

except Exception as e:
    print(f"Error during training: {e}")
    # Save checkpoint if possible
    try:
        if len(train_losses) > 0:
            print("Saving model checkpoint from last successful epoch...")
            torch.save(model.state_dict(), "secbert_bilstm_crf_ner_model_checkpoint.pt")
            print("Checkpoint saved!")
    except Exception as ce:
        print(f"Could not save checkpoint: {ce}")

# Plot training loss and validation F1 if we have any data
if train_losses and val_f1s:
    # Plot training loss
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(train_losses) + 1), train_losses, marker='o', label='Training Loss')
    plt.title('Training Loss over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.legend()
    plt.savefig('training_loss.png')
    plt.show()

    # Plot validation F1
    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(val_f1s) + 1), val_f1s, marker='o', color='green', label='Validation F1')
    plt.title('Validation F1 over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('F1 Score')
    plt.grid(True)
    plt.legend()
    plt.savefig('validation_f1.png')
    plt.show()
else:
    print("No training loss or validation F1 data to plot")

# Evaluate on the test set
try:
    print("\nEvaluating on test set...")
    test_report, token_report, test_predictions, test_true_labels, test_f1 = evaluate(model, test_loader, device, tag2idx, idx2tag)
    print("Entity-Level Test Report:")
    print(test_report)
    print("Token-Level Test Report:")
    print(token_report)
    print(f"Test F1 Score: {test_f1:.4f}")
except Exception as e:
    print(f"Error during test evaluation: {e}")
    test_predictions = []
    test_true_labels = []
    test_report = "Evaluation failed"

# Save the test predictions to a file
try:
    print("\nSaving test predictions...")
    with open("test_predictions.txt", "w", encoding="utf-8") as f:
        for i, (sentence, true_labels, pred_labels) in enumerate(zip(test_sentences, test_true_labels, test_predictions)):
            for j, (word, true_label, pred_label) in enumerate(zip(sentence, true_labels, pred_labels)):
                f.write(f"{word} {true_label} {pred_label}\n")
            f.write("\n")
    print("Test predictions saved to test_predictions.txt")
except Exception as e:
    print(f"Error saving predictions: {e}")
    print("Trying alternative saving method...")
    try:
        with open("test_predictions_simple.txt", "w", encoding="utf-8") as f:
            for i, sentence in enumerate(test_sentences):
                for j, word in enumerate(sentence):
                    pred_label = "O"  # Default prediction if there was an error
                    true_label = "O"  # Default true label if there was an error

                    # Try to get actual predictions if available
                    if i < len(test_predictions) and j < len(test_predictions[i]):
                        pred_label = test_predictions[i][j]

                    # Try to get actual true labels if available
                    if i < len(test_true_labels) and j < len(test_true_labels[i]):
                        true_label = test_true_labels[i][j]

                    f.write(f"{word} {true_label} {pred_label}\n")
                f.write("\n")
        print("Simplified test predictions saved to test_predictions_simple.txt")
    except Exception as e2:
        print(f"Alternative saving also failed: {e2}")

# Function to generate predictions for new sentences
def predict_entities(model, tokenizer, sentences, tag2idx, idx2tag, device, max_len=128):
    model.eval()
    predictions = []

    try:
        for sentence in sentences:
            # Tokenize
            encoding = tokenizer(
                sentence,
                is_split_into_words=True,
                return_offsets_mapping=True,
                padding='max_length',
                truncation=True,
                max_length=max_len,
                return_tensors='pt'
            )

            # Move to device
            input_ids = encoding['input_ids'].to(device)
            attention_mask = encoding['attention_mask'].to(device)
            offsets = encoding['offset_mapping'].squeeze(0).numpy()

            # Get predictions
            with torch.no_grad():
                best_path = model(input_ids=input_ids, attention_mask=attention_mask)[0]

            # Convert predictions to tags
            pred_tags = []
            prev_offset = None
            for i, (offset, pred) in enumerate(zip(offsets, best_path)):
                # Skip special tokens and padding
                if offset[0] == 0 and offset[1] != 0:  # This is the start of a word
                    if i < len(best_path):
                        pred_tags.append(idx2tag.get(pred, "O"))

            # Ensure predictions align with original tokens
            if len(pred_tags) > len(sentence):
                print(f"Warning: Prediction length mismatch: {len(pred_tags)} vs {len(sentence)}")
                pred_tags = pred_tags[:len(sentence)]

            # Pad predictions if necessary
            if len(pred_tags) < len(sentence):
                pred_tags += ['O'] * (len(sentence) - len(pred_tags))

            predictions.append(pred_tags)

    except Exception as e:
        print(f"Error during prediction: {e}")
        # Return empty predictions or dummy predictions in case of error
        predictions = [['O'] * len(sentence) for sentence in sentences]
        print("Returning default 'O' predictions due to error")

    return predictions

# Example of how to use the prediction function
example_sentences = [["John", "lives", "in", "New", "York", "and", "works", "for", "Google"]]
try:
    print("\nTesting prediction function with example sentence...")
    example_predictions = predict_entities(model, tokenizer, example_sentences, tag2idx, idx2tag, device)

    print("\nExample prediction:")
    for sentence, preds in zip(example_sentences, example_predictions):
        for token, tag in zip(sentence, preds):
            print(f"{token} -> {tag}")
except Exception as e:
    print(f"Error in example prediction: {e}")

# Create confusion matrix for visualization if possible
try:
    from sklearn.metrics import confusion_matrix
    import itertools

    flat_preds = [p for sublist in test_predictions for p in sublist]
    flat_labels = [l for sublist in test_true_labels for l in sublist]

    # Get unique tags from the test data
    unique_tags_test = sorted(list(set(flat_labels)))

    # Create confusion matrix
    cm = confusion_matrix(flat_labels, flat_preds, labels=unique_tags_test)

    # Plot confusion matrix
    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=unique_tags_test, yticklabels=unique_tags_test)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.savefig('confusion_matrix.png')
    plt.show()
    print("Confusion matrix saved to confusion_matrix.png")
except Exception as e:
    print(f"Error creating confusion matrix: {e}")

# Generate a comprehensive report
print("\n" + "="*80)
print("NAMED ENTITY RECOGNITION MODEL REPORT")
print("="*80)
print("\nModel Architecture:")
print(f"- SecBERT + BiLSTM ({LSTM_LAYERS} layers) + CRF")
print(f"- Pretrained model: {MODEL_NAME}")
print(f"- LSTM hidden dimension: {LSTM_HIDDEN_DIM}")
print(f"- Dropout rate: {DROPOUT}")

print("\nTraining Details:")
print(f"- Training set size: {len(train_sentences)} sentences")
print(f"- Validation set size: {len(valid_sentences)} sentences")
print(f"- Test set size: {len(test_sentences)} sentences")
print(f"- Number of epochs: {EPOCHS}")
print(f"- Batch size: {BATCH_SIZE}")
print(f"- Initial learning rate: {LEARNING_RATE}")
print(f"- Weight decay: {WEIGHT_DECAY}")
print(f"- Early stopping patience: {PATIENCE}")
print(f"- Early stopping delta: {EARLY_STOPPING_DELTA}")

if train_losses:
    print(f"- Final training loss: {train_losses[-1]:.4f}")
if val_f1s:
    print(f"- Best validation F1: {max(val_f1s):.4f}")

print("\nPerformance Metrics:")
print(f"- Test F1 Score: {test_f1:.4f}")
print("\nEntity-Level Test Report:")
print(test_report)

print("\nBonus Implementation Notes:")
print("1. Used SecBERT instead of standard BERT for better performance in security domain")
print("2. Implemented BiLSTM with multiple layers for better feature extraction")
print("3. Added gradient clipping to prevent exploding gradients")
print("4. Used learning rate scheduler to improve convergence")
print("5. Added both token-level and entity-level (seqeval) evaluation")
print("6. Implemented early stopping to prevent overfitting and reduce training time")

print("\n" + "="*80)
# Out:
# CUDA is available and working. Using device: cuda
# CUDA Version: 12.4
# GPU: Tesla T4
# Loading tokenizer for pretrained model 'jackaduma/SecBERT'...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/378k [00:00<?, ?B/s]
# Tokenizer loaded successfully
# Reading training set: train.txt
# Data format sample (from train.txt):
#   The -> O
#   admin@338 -> B-HackOrg
#   has -> O
#   largely -> O
#   targeted -> O
# Reading validation set: valid.txt
# Data format sample (from valid.txt):
#   We -> O
#   believe -> O
#   that -> O
#   these -> O
#   industries -> O
# Reading test set: test.txt
# Data format sample (from test.txt):
#   Kaspersky -> B-SecTeam
#   believes -> O
#   both -> O
#   Shamoon -> B-HackOrg
#   and -> O
# Training set: 5251 sentences
# Validation set: 662 sentences
# Test set: 664 sentences
#
# Sample from training data:
# The -> O
# admin@338 -> B-HackOrg
# has -> O
# largely -> O
# targeted -> O
# organizations -> O
# involved -> O
# in -> O
# financial -> B-Idus
# , -> O
#
# Unique tags: ['B-Area', 'B-Exp', 'B-Features', 'B-HackOrg', 'B-Idus', 'B-OffAct', 'B-Org', 'B-Purp', 'B-SamFile', 'B-SecTeam', 'B-Time', 'B-Tool', 'B-Way', 'I-Area', 'I-Exp', 'I-Features', 'I-HackOrg', 'I-Idus', 'I-OffAct', 'I-Org', 'I-Purp', 'I-SamFile', 'I-SecTeam', 'I-Time', 'I-Tool', 'I-Way', 'O']
# Number of unique tags: 27
# Initializing model...
# model.safetensors:   0%|          | 0.00/336M [00:00<?, ?B/s]
# Model successfully initialized and moved to cuda
# Setting up optimizer...
# Optimizer configured successfully
#
# ==================== Epoch 1/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.23it/s, Loss=38.2]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:05<00:00,  8.37it/s]
# /usr/local/lib/python3.11/dist-packages/seqeval/metrics/v1.py:57: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Entity-level metrics - F1: 0.0606, Precision: 0.0965, Recall: 0.0442
# New best model saved with F1: 0.0606
# Training Loss: 38.2094, Validation F1: 0.0606
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.0942    0.6181    0.1635       144
#          Exp     0.0000    0.0000    0.0000       131
#     Features     0.0000    0.0000    0.0000        97
#      HackOrg     0.1400    0.0164    0.0294       426
#         Idus     0.0000    0.0000    0.0000       103
#       OffAct     0.0000    0.0000    0.0000       100
#          Org     0.0000    0.0000    0.0000       112
#         Purp     0.0000    0.0000    0.0000        82
#      SamFile     0.0000    0.0000    0.0000       191
#      SecTeam     0.0000    0.0000    0.0000       178
#         Time     0.0000    0.0000    0.0000       183
#         Tool     0.0000    0.0000    0.0000       317
#          Way     0.0000    0.0000    0.0000       109
#
#    micro avg     0.0965    0.0442    0.0606      2173
#    macro avg     0.0180    0.0488    0.0148      2173
# weighted avg     0.0337    0.0442    0.0166      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.1376    0.9028    0.2388       144
#        B-Exp     0.0000    0.0000    0.0000       131
#   B-Features     0.0000    0.0000    0.0000        97
#    B-HackOrg     0.4800    0.0563    0.1008       426
#       B-Idus     0.0000    0.0000    0.0000       103
#     B-OffAct     0.0000    0.0000    0.0000       100
#        B-Org     0.0000    0.0000    0.0000       111
#       B-Purp     0.0000    0.0000    0.0000        82
#    B-SamFile     0.0000    0.0000    0.0000       191
#    B-SecTeam     0.0000    0.0000    0.0000       178
#       B-Time     0.0000    0.0000    0.0000       183
#       B-Tool     0.0000    0.0000    0.0000       317
#        B-Way     0.0000    0.0000    0.0000       109
#       I-Area     0.0000    0.0000    0.0000        48
#        I-Exp     0.0000    0.0000    0.0000        41
#   I-Features     0.0000    0.0000    0.0000        87
#    I-HackOrg     0.0000    0.0000    0.0000       141
#       I-Idus     0.0000    0.0000    0.0000        37
#     I-OffAct     0.0000    0.0000    0.0000        65
#        I-Org     0.0000    0.0000    0.0000        69
#       I-Purp     0.0000    0.0000    0.0000       130
#    I-SamFile     0.0000    0.0000    0.0000        89
#    I-SecTeam     0.0000    0.0000    0.0000        65
#       I-Time     0.0000    0.0000    0.0000        86
#       I-Tool     0.0000    0.0000    0.0000       156
#        I-Way     0.0000    0.0000    0.0000       107
#            O     0.8505    0.9871    0.9138     14309
#
#     accuracy                         0.8112     17602
#    macro avg     0.0544    0.0721    0.0464     17602
# weighted avg     0.7042    0.8112    0.7472     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 2/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:26<00:00,  2.24it/s, Loss=18.7]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  9.01it/s]
# Entity-level metrics - F1: 0.3108, Precision: 0.3319, Recall: 0.2922
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# New best model saved with F1: 0.3108
# Training Loss: 18.7029, Validation F1: 0.3108
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.3591    0.7431    0.4842       144
#          Exp     0.6434    0.7023    0.6715       131
#     Features     0.2273    0.1031    0.1418        97
#      HackOrg     0.3354    0.5117    0.4052       426
#         Idus     0.3701    0.4563    0.4087       103
#       OffAct     0.0000    0.0000    0.0000       100
#          Org     0.0161    0.0089    0.0115       112
#         Purp     0.0800    0.0244    0.0374        82
#      SamFile     0.3333    0.0052    0.0103       191
#      SecTeam     0.7273    0.0899    0.1600       178
#         Time     0.3587    0.4372    0.3941       183
#         Tool     0.2184    0.1798    0.1972       317
#          Way     0.1818    0.0367    0.0611       109
#
#    micro avg     0.3319    0.2922    0.3108      2173
#    macro avg     0.2962    0.2537    0.2295      2173
# weighted avg     0.3199    0.2922    0.2587      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.4242    0.8750    0.5714       144
#        B-Exp     0.7413    0.8092    0.7737       131
#   B-Features     0.0000    0.0000    0.0000        97
#    B-HackOrg     0.4800    0.7324    0.5799       426
#       B-Idus     0.4961    0.6117    0.5478       103
#     B-OffAct     0.2500    0.0700    0.1094       100
#        B-Org     0.0000    0.0000    0.0000       111
#       B-Purp     0.0000    0.0000    0.0000        82
#    B-SamFile     1.0000    0.0052    0.0104       191
#    B-SecTeam     0.9091    0.1124    0.2000       178
#       B-Time     0.6018    0.7268    0.6584       183
#       B-Tool     0.4096    0.3218    0.3604       317
#        B-Way     0.6875    0.1009    0.1760       109
#       I-Area     0.8438    0.5625    0.6750        48
#        I-Exp     0.6071    0.4146    0.4928        41
#   I-Features     0.5273    0.3333    0.4085        87
#    I-HackOrg     0.2000    0.0071    0.0137       141
#       I-Idus     0.0000    0.0000    0.0000        37
#     I-OffAct     0.5000    0.0615    0.1096        65
#        I-Org     0.3485    0.3333    0.3407        69
#       I-Purp     0.4167    0.1154    0.1807       130
#    I-SamFile     1.0000    0.0225    0.0440        89
#    I-SecTeam     0.0000    0.0000    0.0000        65
#       I-Time     0.6667    0.0465    0.0870        86
#       I-Tool     0.2222    0.0641    0.0995       156
#        I-Way     0.7778    0.1308    0.2240       107
#            O     0.9051    0.9829    0.9424     14309
#
#     accuracy                         0.8573     17602
#    macro avg     0.4820    0.2756    0.2817     17602
# weighted avg     0.8278    0.8573    0.8220     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 3/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.23it/s, Loss=11.6]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.96it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Entity-level metrics - F1: 0.5400, Precision: 0.4911, Recall: 0.5996
# New best model saved with F1: 0.5400
# Training Loss: 11.5894, Validation F1: 0.5400
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.4026    0.8750    0.5514       144
#          Exp     0.8605    0.8473    0.8538       131
#     Features     0.5673    0.6082    0.5871        97
#      HackOrg     0.4790    0.7230    0.5762       426
#         Idus     0.4615    0.5243    0.4909       103
#       OffAct     0.4207    0.6900    0.5227       100
#          Org     0.2326    0.2679    0.2490       112
#         Purp     0.3600    0.3293    0.3439        82
#      SamFile     0.6102    0.1885    0.2880       191
#      SecTeam     0.6441    0.6404    0.6423       178
#         Time     0.8172    0.8306    0.8238       183
#         Tool     0.3648    0.5363    0.4342       317
#          Way     0.5165    0.4312    0.4700       109
#
#    micro avg     0.4911    0.5996    0.5400      2173
#    macro avg     0.5182    0.5763    0.5256      2173
# weighted avg     0.5189    0.5996    0.5346      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.4401    0.9444    0.6004       144
#        B-Exp     0.8898    0.8626    0.8760       131
#   B-Features     0.9259    0.2577    0.4032        97
#    B-HackOrg     0.5914    0.8732    0.7052       426
#       B-Idus     0.6410    0.7282    0.6818       103
#     B-OffAct     0.4521    0.6600    0.5366       100
#        B-Org     0.4697    0.2793    0.3503       111
#       B-Purp     0.5588    0.2317    0.3276        82
#    B-SamFile     0.8000    0.1885    0.3051       191
#    B-SecTeam     0.7931    0.7753    0.7841       178
#       B-Time     0.8647    0.8033    0.8329       183
#       B-Tool     0.4416    0.6088    0.5119       317
#        B-Way     0.6133    0.4220    0.5000       109
#       I-Area     0.6000    0.9375    0.7317        48
#        I-Exp     0.7755    0.9268    0.8444        41
#   I-Features     0.4302    0.8851    0.5789        87
#    I-HackOrg     0.5634    0.5674    0.5654       141
#       I-Idus     0.0000    0.0000    0.0000        37
#     I-OffAct     0.4875    0.6000    0.5379        65
#        I-Org     0.4128    0.6522    0.5056        69
#       I-Purp     0.6047    0.6000    0.6023       130
#    I-SamFile     0.9091    0.4494    0.6015        89
#    I-SecTeam     0.7429    0.4000    0.5200        65
#       I-Time     0.7097    0.7674    0.7374        86
#       I-Tool     0.4315    0.6667    0.5239       156
#        I-Way     0.5977    0.4860    0.5361       107
#            O     0.9706    0.9485    0.9594     14309
#
#     accuracy                         0.8896     17602
#    macro avg     0.6192    0.6119    0.5800     17602
# weighted avg     0.9042    0.8896    0.8899     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 4/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.24it/s, Loss=7.72]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  9.01it/s]
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Entity-level metrics - F1: 0.6203, Precision: 0.5708, Recall: 0.6792
# New best model saved with F1: 0.6203
# Training Loss: 7.7180, Validation F1: 0.6203
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.4760    0.8958    0.6217       144
#          Exp     0.8667    0.8931    0.8797       131
#     Features     0.6281    0.7835    0.6972        97
#      HackOrg     0.6102    0.7277    0.6638       426
#         Idus     0.5000    0.5534    0.5253       103
#       OffAct     0.4702    0.7100    0.5657       100
#          Org     0.3540    0.3571    0.3556       112
#         Purp     0.3540    0.4878    0.4103        82
#      SamFile     0.6380    0.5445    0.5876       191
#      SecTeam     0.7068    0.7584    0.7317       178
#         Time     0.7949    0.8470    0.8201       183
#         Tool     0.4641    0.5710    0.5120       317
#          Way     0.5041    0.5596    0.5304       109
#
#    micro avg     0.5708    0.6792    0.6203      2173
#    macro avg     0.5667    0.6684    0.6078      2173
# weighted avg     0.5823    0.6792    0.6222      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5056    0.9375    0.6569       144
#        B-Exp     0.8955    0.9160    0.9057       131
#   B-Features     0.8000    0.7423    0.7701        97
#    B-HackOrg     0.7301    0.8380    0.7803       426
#       B-Idus     0.6754    0.7476    0.7097       103
#     B-OffAct     0.5037    0.6800    0.5787       100
#        B-Org     0.5775    0.3694    0.4505       111
#       B-Purp     0.5385    0.5122    0.5250        82
#    B-SamFile     0.7267    0.5707    0.6393       191
#    B-SecTeam     0.8245    0.8708    0.8470       178
#       B-Time     0.8396    0.8579    0.8486       183
#       B-Tool     0.5615    0.6341    0.5956       317
#        B-Way     0.6078    0.5688    0.5877       109
#       I-Area     0.6866    0.9583    0.8000        48
#        I-Exp     0.7959    0.9512    0.8667        41
#   I-Features     0.5827    0.9310    0.7168        87
#    I-HackOrg     0.5868    0.6950    0.6364       141
#       I-Idus     0.0000    0.0000    0.0000        37
#     I-OffAct     0.5325    0.6308    0.5775        65
#        I-Org     0.4600    0.6667    0.5444        69
#       I-Purp     0.5337    0.8538    0.6568       130
#    I-SamFile     0.7143    0.7865    0.7487        89
#    I-SecTeam     0.7667    0.7077    0.7360        65
#       I-Time     0.7216    0.8140    0.7650        86
#       I-Tool     0.5385    0.6282    0.5799       156
#        I-Way     0.6111    0.6168    0.6140       107
#            O     0.9775    0.9487    0.9629     14309
#
#     accuracy                         0.9080     17602
#    macro avg     0.6405    0.7198    0.6704     17602
# weighted avg     0.9168    0.9080    0.9105     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 5/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:28<00:00,  2.22it/s, Loss=5.42]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:05<00:00,  8.35it/s]
# Entity-level metrics - F1: 0.6861, Precision: 0.6597, Recall: 0.7147
# New best model saved with F1: 0.6861
# Training Loss: 5.4245, Validation F1: 0.6861
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5185    0.8750    0.6512       144
#          Exp     0.9231    0.9160    0.9195       131
#     Features     0.7788    0.9072    0.8381        97
#      HackOrg     0.6688    0.7488    0.7065       426
#         Idus     0.6226    0.6408    0.6316       103
#       OffAct     0.5906    0.7500    0.6608       100
#          Org     0.5051    0.4464    0.4739       112
#         Purp     0.5093    0.6707    0.5789        82
#      SamFile     0.8028    0.5969    0.6847       191
#      SecTeam     0.7644    0.7472    0.7557       178
#         Time     0.8424    0.8470    0.8447       183
#         Tool     0.5343    0.5899    0.5607       317
#          Way     0.6436    0.5963    0.6190       109
#
#    micro avg     0.6597    0.7147    0.6861      2173
#    macro avg     0.6695    0.7179    0.6866      2173
# weighted avg     0.6722    0.7147    0.6872      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5375    0.8958    0.6719       144
#        B-Exp     0.9685    0.9389    0.9535       131
#   B-Features     0.8333    0.8763    0.8543        97
#    B-HackOrg     0.7747    0.8474    0.8094       426
#       B-Idus     0.7642    0.7864    0.7751       103
#     B-OffAct     0.6000    0.7200    0.6545       100
#        B-Org     0.6250    0.4505    0.5236       111
#       B-Purp     0.6444    0.7073    0.6744        82
#    B-SamFile     0.8667    0.6126    0.7178       191
#    B-SecTeam     0.9006    0.8652    0.8825       178
#       B-Time     0.8827    0.8634    0.8729       183
#       B-Tool     0.6066    0.6372    0.6215       317
#        B-Way     0.7802    0.6514    0.7100       109
#       I-Area     0.7419    0.9583    0.8364        48
#        I-Exp     0.8298    0.9512    0.8864        41
#   I-Features     0.7699    1.0000    0.8700        87
#    I-HackOrg     0.6643    0.6738    0.6690       141
#       I-Idus     0.9333    0.3784    0.5385        37
#     I-OffAct     0.6721    0.6308    0.6508        65
#        I-Org     0.5357    0.6522    0.5882        69
#       I-Purp     0.6364    0.9154    0.7508       130
#    I-SamFile     0.8875    0.7978    0.8402        89
#    I-SecTeam     0.8367    0.6308    0.7193        65
#       I-Time     0.7553    0.8256    0.7889        86
#       I-Tool     0.6645    0.6474    0.6558       156
#        I-Way     0.7157    0.6822    0.6986       107
#            O     0.9732    0.9639    0.9685     14309
#
#     accuracy                         0.9259     17602
#    macro avg     0.7556    0.7615    0.7475     17602
# weighted avg     0.9302    0.9259    0.9265     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 6/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:31<00:00,  2.17it/s, Loss=3.81]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.82it/s]
# Entity-level metrics - F1: 0.7179, Precision: 0.6923, Recall: 0.7455
# New best model saved with F1: 0.7179
# Training Loss: 3.8079, Validation F1: 0.7179
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.4856    0.8194    0.6098       144
#          Exp     0.9612    0.9466    0.9538       131
#     Features     0.7787    0.9794    0.8676        97
#      HackOrg     0.7084    0.7300    0.7191       426
#         Idus     0.7685    0.8058    0.7867       103
#       OffAct     0.5423    0.7700    0.6364       100
#          Org     0.5978    0.4911    0.5392       112
#         Purp     0.5619    0.7195    0.6310        82
#      SamFile     0.8142    0.7801    0.7968       191
#      SecTeam     0.7803    0.7584    0.7692       178
#         Time     0.8644    0.8361    0.8500       183
#         Tool     0.6106    0.5836    0.5968       317
#          Way     0.6129    0.6972    0.6524       109
#
#    micro avg     0.6923    0.7455    0.7179      2173
#    macro avg     0.6990    0.7629    0.7238      2173
# weighted avg     0.7053    0.7455    0.7202      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5270    0.8819    0.6597       144
#        B-Exp     0.9840    0.9389    0.9609       131
#   B-Features     0.8087    0.9588    0.8774        97
#    B-HackOrg     0.8093    0.8169    0.8131       426
#       B-Idus     0.8148    0.8544    0.8341       103
#     B-OffAct     0.5630    0.7600    0.6468       100
#        B-Org     0.7051    0.4955    0.5820       111
#       B-Purp     0.7143    0.7927    0.7514        82
#    B-SamFile     0.8547    0.8010    0.8270       191
#    B-SecTeam     0.9006    0.8652    0.8825       178
#       B-Time     0.9123    0.8525    0.8814       183
#       B-Tool     0.6912    0.6215    0.6545       317
#        B-Way     0.7043    0.7431    0.7232       109
#       I-Area     0.6765    0.9583    0.7931        48
#        I-Exp     0.8913    1.0000    0.9425        41
#   I-Features     0.7982    1.0000    0.8878        87
#    I-HackOrg     0.7121    0.6667    0.6886       141
#       I-Idus     0.9677    0.8108    0.8824        37
#     I-OffAct     0.6462    0.6462    0.6462        65
#        I-Org     0.6267    0.6812    0.6528        69
#       I-Purp     0.7143    0.9231    0.8054       130
#    I-SamFile     0.9186    0.8876    0.9029        89
#    I-SecTeam     0.8182    0.6923    0.7500        65
#       I-Time     0.8068    0.8256    0.8161        86
#       I-Tool     0.6867    0.6603    0.6732       156
#        I-Way     0.6880    0.8037    0.7414       107
#            O     0.9748    0.9646    0.9697     14309
#
#     accuracy                         0.9323     17602
#    macro avg     0.7746    0.8112    0.7869     17602
# weighted avg     0.9361    0.9323    0.9332     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 7/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.23it/s, Loss=2.77]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:05<00:00,  8.24it/s]
# Entity-level metrics - F1: 0.7352, Precision: 0.7078, Recall: 0.7648
# New best model saved with F1: 0.7352
# Training Loss: 2.7736, Validation F1: 0.7352
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.4805    0.8542    0.6150       144
#          Exp     0.9615    0.9542    0.9579       131
#     Features     0.8393    0.9691    0.8995        97
#      HackOrg     0.7295    0.7535    0.7413       426
#         Idus     0.8654    0.8738    0.8696       103
#       OffAct     0.5746    0.7700    0.6581       100
#          Org     0.6591    0.5179    0.5800       112
#         Purp     0.6036    0.8171    0.6943        82
#      SamFile     0.7352    0.8429    0.7854       191
#      SecTeam     0.8155    0.7697    0.7919       178
#         Time     0.8564    0.8470    0.8516       183
#         Tool     0.6310    0.5394    0.5816       317
#          Way     0.6194    0.7615    0.6831       109
#
#    micro avg     0.7078    0.7648    0.7352      2173
#    macro avg     0.7208    0.7900    0.7469      2173
# weighted avg     0.7212    0.7648    0.7363      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5098    0.9028    0.6516       144
#        B-Exp     0.9688    0.9466    0.9575       131
#   B-Features     0.8545    0.9691    0.9082        97
#    B-HackOrg     0.8318    0.8357    0.8337       426
#       B-Idus     0.8750    0.8835    0.8792       103
#     B-OffAct     0.5969    0.7700    0.6725       100
#        B-Org     0.7531    0.5495    0.6354       111
#       B-Purp     0.7100    0.8659    0.7802        82
#    B-SamFile     0.7820    0.8639    0.8209       191
#    B-SecTeam     0.9226    0.8708    0.8960       178
#       B-Time     0.9034    0.8689    0.8858       183
#       B-Tool     0.7395    0.6088    0.6678       317
#        B-Way     0.6850    0.7982    0.7373       109
#       I-Area     0.6970    0.9583    0.8070        48
#        I-Exp     0.9111    1.0000    0.9535        41
#   I-Features     0.9355    1.0000    0.9667        87
#    I-HackOrg     0.6667    0.7234    0.6939       141
#       I-Idus     0.9706    0.8919    0.9296        37
#     I-OffAct     0.7119    0.6462    0.6774        65
#        I-Org     0.6765    0.6667    0.6715        69
#       I-Purp     0.7427    0.9769    0.8439       130
#    I-SamFile     0.8020    0.9101    0.8526        89
#    I-SecTeam     0.8846    0.7077    0.7863        65
#       I-Time     0.8000    0.8372    0.8182        86
#       I-Tool     0.7000    0.5833    0.6364       156
#        I-Way     0.7143    0.8411    0.7725       107
#            O     0.9765    0.9647    0.9706     14309
#
#     accuracy                         0.9357     17602
#    macro avg     0.7897    0.8312    0.8039     17602
# weighted avg     0.9400    0.9357    0.9366     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 8/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.23it/s, Loss=2.03]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.91it/s]
# Entity-level metrics - F1: 0.7453, Precision: 0.7167, Recall: 0.7763
# New best model saved with F1: 0.7453
# Training Loss: 2.0303, Validation F1: 0.7453
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.4737    0.8750    0.6146       144
#          Exp     0.9462    0.9389    0.9425       131
#     Features     0.8440    0.9485    0.8932        97
#      HackOrg     0.6985    0.7723    0.7336       426
#         Idus     0.8679    0.8932    0.8804       103
#       OffAct     0.6033    0.7300    0.6606       100
#          Org     0.7195    0.5268    0.6082       112
#         Purp     0.7551    0.9024    0.8222        82
#      SamFile     0.7407    0.8377    0.7862       191
#      SecTeam     0.8256    0.7978    0.8114       178
#         Time     0.8306    0.8306    0.8306       183
#         Tool     0.6396    0.5710    0.6033       317
#          Way     0.7179    0.7706    0.7434       109
#
#    micro avg     0.7167    0.7763    0.7453      2173
#    macro avg     0.7433    0.7996    0.7639      2173
# weighted avg     0.7295    0.7763    0.7466      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.4962    0.9097    0.6422       144
#        B-Exp     0.9538    0.9466    0.9502       131
#   B-Features     0.8611    0.9588    0.9073        97
#    B-HackOrg     0.8000    0.8638    0.8307       426
#       B-Idus     0.8857    0.9029    0.8942       103
#     B-OffAct     0.6325    0.7400    0.6820       100
#        B-Org     0.7949    0.5586    0.6561       111
#       B-Purp     0.8280    0.9390    0.8800        82
#    B-SamFile     0.7952    0.8743    0.8329       191
#    B-SecTeam     0.9176    0.8764    0.8966       178
#       B-Time     0.8800    0.8415    0.8603       183
#       B-Tool     0.7313    0.6183    0.6701       317
#        B-Way     0.7788    0.8073    0.7928       109
#       I-Area     0.7419    0.9583    0.8364        48
#        I-Exp     0.8913    1.0000    0.9425        41
#   I-Features     0.8776    0.9885    0.9297        87
#    I-HackOrg     0.6646    0.7447    0.7023       141
#       I-Idus     0.8718    0.9189    0.8947        37
#     I-OffAct     0.7193    0.6308    0.6721        65
#        I-Org     0.7333    0.6377    0.6822        69
#       I-Purp     0.8431    0.9923    0.9117       130
#    I-SamFile     0.7921    0.8989    0.8421        89
#    I-SecTeam     0.8226    0.7846    0.8031        65
#       I-Time     0.6990    0.8372    0.7619        86
#       I-Tool     0.7143    0.6410    0.6757       156
#        I-Way     0.7863    0.8598    0.8214       107
#            O     0.9780    0.9647    0.9713     14309
#
#     accuracy                         0.9378     17602
#    macro avg     0.7959    0.8405    0.8127     17602
# weighted avg     0.9419    0.9378    0.9388     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 9/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:28<00:00,  2.22it/s, Loss=1.58]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  9.00it/s]
# Entity-level metrics - F1: 0.7630, Precision: 0.7426, Recall: 0.7846
# New best model saved with F1: 0.7630
# Training Loss: 1.5850, Validation F1: 0.7630
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.4980    0.8611    0.6310       144
#          Exp     0.9773    0.9847    0.9810       131
#     Features     0.8120    0.9794    0.8879        97
#      HackOrg     0.7541    0.7629    0.7585       426
#         Idus     0.8922    0.8835    0.8878       103
#       OffAct     0.6857    0.7200    0.7024       100
#          Org     0.6505    0.5982    0.6233       112
#         Purp     0.6549    0.9024    0.7590        82
#      SamFile     0.8342    0.8429    0.8385       191
#      SecTeam     0.8521    0.8090    0.8300       178
#         Time     0.8362    0.8087    0.8222       183
#         Tool     0.6609    0.6025    0.6304       317
#          Way     0.7241    0.7706    0.7467       109
#
#    micro avg     0.7426    0.7846    0.7630      2173
#    macro avg     0.7563    0.8097    0.7768      2173
# weighted avg     0.7543    0.7846    0.7648      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5282    0.9097    0.6684       144
#        B-Exp     0.9847    0.9847    0.9847       131
#   B-Features     0.8407    0.9794    0.9048        97
#    B-HackOrg     0.8314    0.8216    0.8264       426
#       B-Idus     0.9200    0.8932    0.9064       103
#     B-OffAct     0.7129    0.7200    0.7164       100
#        B-Org     0.7143    0.6306    0.6699       111
#       B-Purp     0.7383    0.9634    0.8360        82
#    B-SamFile     0.8594    0.8639    0.8616       191
#    B-SecTeam     0.9281    0.8708    0.8986       178
#       B-Time     0.8902    0.8415    0.8652       183
#       B-Tool     0.7565    0.6467    0.6973       317
#        B-Way     0.7739    0.8165    0.7946       109
#       I-Area     0.7500    0.9375    0.8333        48
#        I-Exp     0.9762    1.0000    0.9880        41
#   I-Features     0.9062    1.0000    0.9508        87
#    I-HackOrg     0.7114    0.7518    0.7310       141
#       I-Idus     0.9000    0.9730    0.9351        37
#     I-OffAct     0.7321    0.6308    0.6777        65
#        I-Org     0.6974    0.7681    0.7310        69
#       I-Purp     0.7738    1.0000    0.8725       130
#    I-SamFile     0.9101    0.9101    0.9101        89
#    I-SecTeam     0.8594    0.8462    0.8527        65
#       I-Time     0.7245    0.8256    0.7717        86
#       I-Tool     0.6871    0.6474    0.6667       156
#        I-Way     0.8364    0.8598    0.8479       107
#            O     0.9764    0.9669    0.9716     14309
#
#     accuracy                         0.9408     17602
#    macro avg     0.8118    0.8540    0.8285     17602
# weighted avg     0.9439    0.9408    0.9415     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 10/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:32<00:00,  2.16it/s, Loss=1.19]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.61it/s]
# Entity-level metrics - F1: 0.7655, Precision: 0.7228, Recall: 0.8136
# New best model saved with F1: 0.7655
# Training Loss: 1.1921, Validation F1: 0.7655
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5556    0.8681    0.6775       144
#          Exp     0.9847    0.9847    0.9847       131
#     Features     0.7561    0.9588    0.8455        97
#      HackOrg     0.6929    0.8052    0.7448       426
#         Idus     0.8598    0.8932    0.8762       103
#       OffAct     0.6160    0.7700    0.6844       100
#          Org     0.7556    0.6071    0.6733       112
#         Purp     0.7009    0.9146    0.7937        82
#      SamFile     0.8173    0.8429    0.8299       191
#      SecTeam     0.8182    0.8090    0.8136       178
#         Time     0.8644    0.8361    0.8500       183
#         Tool     0.5796    0.7003    0.6343       317
#          Way     0.7818    0.7890    0.7854       109
#
#    micro avg     0.7228    0.8136    0.7655      2173
#    macro avg     0.7525    0.8292    0.7841      2173
# weighted avg     0.7357    0.8136    0.7688      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5848    0.9097    0.7120       144
#        B-Exp     0.9847    0.9847    0.9847       131
#   B-Features     0.7899    0.9691    0.8704        97
#    B-HackOrg     0.7702    0.8732    0.8185       426
#       B-Idus     0.8972    0.9320    0.9143       103
#     B-OffAct     0.6230    0.7600    0.6847       100
#        B-Org     0.8095    0.6126    0.6974       111
#       B-Purp     0.7723    0.9512    0.8525        82
#    B-SamFile     0.8608    0.8743    0.8675       191
#    B-SecTeam     0.9148    0.9045    0.9096       178
#       B-Time     0.9080    0.8634    0.8852       183
#       B-Tool     0.6595    0.7697    0.7103       317
#        B-Way     0.8333    0.8257    0.8295       109
#       I-Area     0.7541    0.9583    0.8440        48
#        I-Exp     0.9762    1.0000    0.9880        41
#   I-Features     0.8131    1.0000    0.8969        87
#    I-HackOrg     0.6400    0.7943    0.7089       141
#       I-Idus     0.9211    0.9459    0.9333        37
#     I-OffAct     0.7368    0.6462    0.6885        65
#        I-Org     0.7606    0.7826    0.7714        69
#       I-Purp     0.8012    0.9923    0.8866       130
#    I-SamFile     0.8913    0.9213    0.9061        89
#    I-SecTeam     0.8571    0.7385    0.7934        65
#       I-Time     0.8068    0.8256    0.8161        86
#       I-Tool     0.6304    0.7436    0.6824       156
#        I-Way     0.8704    0.8785    0.8744       107
#            O     0.9825    0.9591    0.9706     14309
#
#     accuracy                         0.9400     17602
#    macro avg     0.8092    0.8673    0.8332     17602
# weighted avg     0.9459    0.9400    0.9418     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 11/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:28<00:00,  2.22it/s, Loss=0.948]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.92it/s]
# Entity-level metrics - F1: 0.7688, Precision: 0.7409, Recall: 0.7989
# New best model saved with F1: 0.7688
# Training Loss: 0.9476, Validation F1: 0.7688
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5644    0.8819    0.6883       144
#          Exp     0.9773    0.9847    0.9810       131
#     Features     0.7805    0.9897    0.8727        97
#      HackOrg     0.7113    0.7864    0.7469       426
#         Idus     0.8716    0.9223    0.8962       103
#       OffAct     0.6818    0.7500    0.7143       100
#          Org     0.7368    0.6250    0.6763       112
#         Purp     0.6577    0.8902    0.7565        82
#      SamFile     0.7511    0.8691    0.8058       191
#      SecTeam     0.8430    0.8146    0.8286       178
#         Time     0.8516    0.8470    0.8493       183
#         Tool     0.6514    0.5836    0.6156       317
#          Way     0.7870    0.7798    0.7834       109
#
#    micro avg     0.7409    0.7989    0.7688      2173
#    macro avg     0.7589    0.8250    0.7858      2173
# weighted avg     0.7474    0.7989    0.7682      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5874    0.9097    0.7139       144
#        B-Exp     0.9847    0.9847    0.9847       131
#   B-Features     0.8000    0.9897    0.8848        97
#    B-HackOrg     0.7965    0.8545    0.8245       426
#       B-Idus     0.8981    0.9417    0.9194       103
#     B-OffAct     0.7048    0.7400    0.7220       100
#        B-Org     0.7802    0.6396    0.7030       111
#       B-Purp     0.7500    0.9878    0.8526        82
#    B-SamFile     0.7818    0.9005    0.8370       191
#    B-SecTeam     0.9302    0.8989    0.9143       178
#       B-Time     0.8977    0.8634    0.8802       183
#       B-Tool     0.7390    0.6341    0.6825       317
#        B-Way     0.8224    0.8073    0.8148       109
#       I-Area     0.7344    0.9792    0.8393        48
#        I-Exp     0.9318    1.0000    0.9647        41
#   I-Features     0.8131    1.0000    0.8969        87
#    I-HackOrg     0.6369    0.8085    0.7125       141
#       I-Idus     0.8780    0.9730    0.9231        37
#     I-OffAct     0.7500    0.6462    0.6942        65
#        I-Org     0.7123    0.7536    0.7324        69
#       I-Purp     0.7927    1.0000    0.8844       130
#    I-SamFile     0.8351    0.9101    0.8710        89
#    I-SecTeam     0.8621    0.7692    0.8130        65
#       I-Time     0.7660    0.8372    0.8000        86
#       I-Tool     0.6824    0.6474    0.6645       156
#        I-Way     0.8532    0.8692    0.8611       107
#            O     0.9799    0.9641    0.9719     14309
#
#     accuracy                         0.9410     17602
#    macro avg     0.8037    0.8633    0.8282     17602
# weighted avg     0.9446    0.9410    0.9418     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 12/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:28<00:00,  2.22it/s, Loss=0.787]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.87it/s]
# Entity-level metrics - F1: 0.7705, Precision: 0.7351, Recall: 0.8095
# New best model saved with F1: 0.7705
# Training Loss: 0.7866, Validation F1: 0.7705
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5169    0.8472    0.6421       144
#          Exp     0.9627    0.9847    0.9736       131
#     Features     0.8261    0.9794    0.8962        97
#      HackOrg     0.7263    0.7911    0.7573       426
#         Idus     0.8509    0.9417    0.8940       103
#       OffAct     0.5969    0.7700    0.6725       100
#          Org     0.7188    0.6161    0.6635       112
#         Purp     0.5736    0.9024    0.7014        82
#      SamFile     0.9011    0.8586    0.8794       191
#      SecTeam     0.8430    0.8146    0.8286       178
#         Time     0.8531    0.8251    0.8389       183
#         Tool     0.6375    0.6656    0.6512       317
#          Way     0.7719    0.8073    0.7892       109
#
#    micro avg     0.7351    0.8095    0.7705      2173
#    macro avg     0.7522    0.8311    0.7837      2173
# weighted avg     0.7499    0.8095    0.7741      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5603    0.9028    0.6915       144
#        B-Exp     0.9627    0.9847    0.9736       131
#   B-Features     0.8584    1.0000    0.9238        97
#    B-HackOrg     0.8102    0.8615    0.8350       426
#       B-Idus     0.8750    0.9515    0.9116       103
#     B-OffAct     0.6333    0.7600    0.6909       100
#        B-Org     0.7778    0.6306    0.6965       111
#       B-Purp     0.6639    0.9878    0.7941        82
#    B-SamFile     0.9176    0.8743    0.8954       191
#    B-SecTeam     0.9360    0.9045    0.9200       178
#       B-Time     0.9017    0.8525    0.8764       183
#       B-Tool     0.7284    0.7192    0.7238       317
#        B-Way     0.7965    0.8257    0.8108       109
#       I-Area     0.6438    0.9792    0.7769        48
#        I-Exp     0.9318    1.0000    0.9647        41
#   I-Features     0.8286    1.0000    0.9062        87
#    I-HackOrg     0.6497    0.8156    0.7233       141
#       I-Idus     0.8605    1.0000    0.9250        37
#     I-OffAct     0.6667    0.6462    0.6562        65
#        I-Org     0.7162    0.7681    0.7413        69
#       I-Purp     0.7303    1.0000    0.8442       130
#    I-SamFile     0.8925    0.9326    0.9121        89
#    I-SecTeam     0.8621    0.7692    0.8130        65
#       I-Time     0.7500    0.8372    0.7912        86
#       I-Tool     0.6391    0.6923    0.6646       156
#        I-Way     0.8868    0.8785    0.8826       107
#            O     0.9809    0.9593    0.9700     14309
#
#     accuracy                         0.9394     17602
#    macro avg     0.7948    0.8716    0.8265     17602
# weighted avg     0.9452    0.9394    0.9412     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 13/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:26<00:00,  2.24it/s, Loss=0.656]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  9.02it/s]
# Entity-level metrics - F1: 0.7881, Precision: 0.7588, Recall: 0.8196
# New best model saved with F1: 0.7881
# Training Loss: 0.6564, Validation F1: 0.7881
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5888    0.8750    0.7039       144
#          Exp     0.9845    0.9695    0.9769       131
#     Features     0.8220    1.0000    0.9023        97
#      HackOrg     0.7343    0.7981    0.7649       426
#         Idus     0.8435    0.9417    0.8899       103
#       OffAct     0.6446    0.7800    0.7059       100
#          Org     0.7234    0.6071    0.6602       112
#         Purp     0.6964    0.9512    0.8041        82
#      SamFile     0.8639    0.8639    0.8639       191
#      SecTeam     0.8563    0.8371    0.8466       178
#         Time     0.8743    0.8361    0.8547       183
#         Tool     0.6616    0.6845    0.6729       317
#          Way     0.7611    0.7890    0.7748       109
#
#    micro avg     0.7588    0.8196    0.7881      2173
#    macro avg     0.7734    0.8410    0.8016      2173
# weighted avg     0.7666    0.8196    0.7891      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.6114    0.8958    0.7268       144
#        B-Exp     0.9845    0.9695    0.9769       131
#   B-Features     0.8362    1.0000    0.9108        97
#    B-HackOrg     0.8128    0.8662    0.8386       426
#       B-Idus     0.8829    0.9515    0.9159       103
#     B-OffAct     0.6552    0.7600    0.7037       100
#        B-Org     0.7667    0.6216    0.6866       111
#       B-Purp     0.7339    0.9756    0.8377        82
#    B-SamFile     0.9032    0.8796    0.8912       191
#    B-SecTeam     0.9310    0.9101    0.9205       178
#       B-Time     0.9186    0.8634    0.8901       183
#       B-Tool     0.7215    0.7192    0.7204       317
#        B-Way     0.8182    0.8257    0.8219       109
#       I-Area     0.7705    0.9792    0.8624        48
#        I-Exp     1.0000    1.0000    1.0000        41
#   I-Features     0.8447    1.0000    0.9158        87
#    I-HackOrg     0.6444    0.8227    0.7227       141
#       I-Idus     0.8409    1.0000    0.9136        37
#     I-OffAct     0.7414    0.6615    0.6992        65
#        I-Org     0.7027    0.7536    0.7273        69
#       I-Purp     0.8165    0.9923    0.8958       130
#    I-SamFile     0.9111    0.9213    0.9162        89
#    I-SecTeam     0.8387    0.8000    0.8189        65
#       I-Time     0.8046    0.8140    0.8092        86
#       I-Tool     0.6805    0.7372    0.7077       156
#        I-Way     0.8774    0.8692    0.8732       107
#            O     0.9803    0.9643    0.9722     14309
#
#     accuracy                         0.9438     17602
#    macro avg     0.8159    0.8724    0.8398     17602
# weighted avg     0.9476    0.9438    0.9449     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 14/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.23it/s, Loss=0.564]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.85it/s]
# Entity-level metrics - F1: 0.7852, Precision: 0.7603, Recall: 0.8118
# No significant improvement. Patience: 1/3
# Training Loss: 0.5638, Validation F1: 0.7852
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5619    0.8819    0.6865       144
#          Exp     0.9847    0.9847    0.9847       131
#     Features     0.8083    1.0000    0.8940        97
#      HackOrg     0.7366    0.8075    0.7704       426
#         Idus     0.8981    0.9417    0.9194       103
#       OffAct     0.6518    0.7300    0.6887       100
#          Org     0.7300    0.6518    0.6887       112
#         Purp     0.6897    0.9756    0.8081        82
#      SamFile     0.8730    0.8639    0.8684       191
#      SecTeam     0.8494    0.7921    0.8198       178
#         Time     0.8462    0.8415    0.8438       183
#         Tool     0.6655    0.6215    0.6427       317
#          Way     0.8131    0.7982    0.8056       109
#
#    micro avg     0.7603    0.8118    0.7852      2173
#    macro avg     0.7776    0.8377    0.8016      2173
# weighted avg     0.7688    0.8118    0.7858      2173
#
# Token-Level Validation Report:
# ...
#   I-Features     0.8614    1.0000    0.9255        87
#    I-HackOrg     0.7012    0.8156    0.7541       141
#       I-Idus     0.9474    0.9730    0.9600        37
#     I-OffAct     0.7593    0.6308    0.6891        65
#        I-Org     0.7105    0.7826    0.7448        69
#       I-Purp     0.8280    1.0000    0.9059       130
#    I-SamFile     0.9022    0.9326    0.9171        89
#    I-SecTeam     0.8846    0.7077    0.7863        65
#       I-Time     0.7802    0.8256    0.8023        86
#       I-Tool     0.7376    0.6667    0.7003       156
#        I-Way     0.8624    0.8785    0.8704       107
#            O     0.9785    0.9676    0.9730     14309
#
#     accuracy                         0.9452     17602
#    macro avg     0.8277    0.8667    0.8425     17602
# weighted avg     0.9481    0.9452    0.9458     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 15/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.24it/s, Loss=0.461]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.89it/s]
# Entity-level metrics - F1: 0.7902, Precision: 0.7633, Recall: 0.8191
# New best model saved with F1: 0.7902
# Training Loss: 0.4614, Validation F1: 0.7902
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5474    0.8819    0.6755       144
#          Exp     0.9847    0.9847    0.9847       131
#     Features     0.8291    1.0000    0.9065        97
#      HackOrg     0.7361    0.8052    0.7691       426
#         Idus     0.8972    0.9320    0.9143       103
#       OffAct     0.6574    0.7100    0.6827       100
#          Org     0.7400    0.6607    0.6981       112
#         Purp     0.7339    0.9756    0.8377        82
#      SamFile     0.9116    0.8639    0.8871       191
#      SecTeam     0.8580    0.8146    0.8357       178
#         Time     0.8671    0.8197    0.8427       183
#         Tool     0.6485    0.6751    0.6615       317
#          Way     0.8165    0.8165    0.8165       109
#
#    micro avg     0.7633    0.8191    0.7902      2173
#    macro avg     0.7867    0.8415    0.8086      2173
# weighted avg     0.7746    0.8191    0.7926      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5628    0.9028    0.6933       144
#        B-Exp     0.9847    0.9847    0.9847       131
#   B-Features     0.8584    1.0000    0.9238        97
#    B-HackOrg     0.8200    0.8662    0.8425       426
#       B-Idus     0.9135    0.9223    0.9179       103
#     B-OffAct     0.6762    0.7100    0.6927       100
#        B-Org     0.7684    0.6577    0.7087       111
#       B-Purp     0.7810    1.0000    0.8770        82
#    B-SamFile     0.9227    0.8743    0.8978       191
#    B-SecTeam     0.9586    0.9101    0.9337       178
#       B-Time     0.9118    0.8470    0.8782       183
#       B-Tool     0.7201    0.7224    0.7213       317
#        B-Way     0.8505    0.8349    0.8426       109
#       I-Area     0.7833    0.9792    0.8704        48
#        I-Exp     1.0000    1.0000    1.0000        41
#   I-Features     0.8529    1.0000    0.9206        87
#    I-HackOrg     0.6727    0.7872    0.7255       141
#       I-Idus     0.8780    0.9730    0.9231        37
#     I-OffAct     0.7500    0.6462    0.6942        65
#        I-Org     0.7200    0.7826    0.7500        69
#       I-Purp     0.8333    1.0000    0.9091       130
#    I-SamFile     0.9425    0.9213    0.9318        89
#    I-SecTeam     0.9057    0.7385    0.8136        65
#       I-Time     0.8161    0.8256    0.8208        86
#       I-Tool     0.6928    0.6795    0.6861       156
#        I-Way     0.8468    0.8785    0.8624       107
#            O     0.9786    0.9667    0.9726     14309
#
#     accuracy                         0.9449     17602
#    macro avg     0.8297    0.8671    0.8442     17602
# weighted avg     0.9481    0.9449    0.9458     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 16/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.23it/s, Loss=0.437]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.88it/s]
# Entity-level metrics - F1: 0.7893, Precision: 0.7672, Recall: 0.8127
# No significant improvement. Patience: 1/3
# Training Loss: 0.4372, Validation F1: 0.7893
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5586    0.8611    0.6776       144
#          Exp     0.9773    0.9847    0.9810       131
#     Features     0.8017    1.0000    0.8899        97
#      HackOrg     0.7540    0.7840    0.7687       426
#         Idus     0.9151    0.9417    0.9282       103
#       OffAct     0.6818    0.7500    0.7143       100
#          Org     0.6944    0.6696    0.6818       112
#         Purp     0.7941    0.9878    0.8804        82
#      SamFile     0.8549    0.8639    0.8594       191
#      SecTeam     0.8304    0.7978    0.8138       178
#         Time     0.8909    0.8033    0.8448       183
#         Tool     0.6871    0.6719    0.6794       317
#          Way     0.7311    0.7982    0.7632       109
#
#    micro avg     0.7672    0.8127    0.7893      2173
#    macro avg     0.7824    0.8395    0.8063      2173
# weighted avg     0.7751    0.8127    0.7904      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.5818    0.8889    0.7033       144
#        B-Exp     0.9773    0.9847    0.9810       131
#   B-Features     0.8220    1.0000    0.9023        97
#    B-HackOrg     0.8353    0.8451    0.8401       426
#       B-Idus     0.9238    0.9417    0.9327       103
#     B-OffAct     0.7103    0.7600    0.7343       100
#        B-Org     0.7282    0.6757    0.7009       111
#       B-Purp     0.8119    1.0000    0.8962        82
#    B-SamFile     0.8906    0.8953    0.8930       191
#    B-SecTeam     0.9474    0.9101    0.9284       178
#       B-Time     0.9363    0.8033    0.8647       183
#       B-Tool     0.7508    0.7129    0.7314       317
#        B-Way     0.7778    0.8349    0.8053       109
#       I-Area     0.7581    0.9792    0.8545        48
#        I-Exp     1.0000    1.0000    1.0000        41
#   I-Features     0.8700    1.0000    0.9305        87
#    I-HackOrg     0.6879    0.7660    0.7248       141
#       I-Idus     0.9474    0.9730    0.9600        37
#     I-OffAct     0.7500    0.6462    0.6942        65
#        I-Org     0.7105    0.7826    0.7448        69
#       I-Purp     0.8784    1.0000    0.9353       130
#    I-SamFile     0.9524    0.8989    0.9249        89
#    I-SecTeam     0.9000    0.6923    0.7826        65
#       I-Time     0.8046    0.8140    0.8092        86
#       I-Tool     0.7078    0.6987    0.7032       156
#        I-Way     0.8142    0.8598    0.8364       107
#            O     0.9777    0.9690    0.9733     14309
#
#     accuracy                         0.9457     17602
#    macro avg     0.8316    0.8642    0.8440     17602
# weighted avg     0.9482    0.9457    0.9464     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 17/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:26<00:00,  2.24it/s, Loss=0.381]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.82it/s]
# Entity-level metrics - F1: 0.7880, Precision: 0.7696, Recall: 0.8072
# No significant improvement. Patience: 2/3
# Training Loss: 0.3814, Validation F1: 0.7880
# Entity-Level Validation Report:
#               precision    recall  f1-score   support
#
#         Area     0.5841    0.8681    0.6983       144
#          Exp     0.9776    1.0000    0.9887       131
#     Features     0.8291    1.0000    0.9065        97
#      HackOrg     0.7293    0.7840    0.7557       426
#         Idus     0.9327    0.9417    0.9372       103
#       OffAct     0.6792    0.7200    0.6990       100
#          Org     0.7059    0.6429    0.6729       112
#         Purp     0.8000    0.9756    0.8791        82
#      SamFile     0.8691    0.8691    0.8691       191
#      SecTeam     0.8323    0.7809    0.8058       178
#         Time     0.8488    0.7978    0.8225       183
#         Tool     0.6913    0.6498    0.6699       317
#          Way     0.7672    0.8165    0.7911       109
#
#    micro avg     0.7696    0.8072    0.7880      2173
#    macro avg     0.7882    0.8343    0.8074      2173
# weighted avg     0.7750    0.8072    0.7880      2173
#
# Token-Level Validation Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.6056    0.8958    0.7227       144
#        B-Exp     0.9850    1.0000    0.9924       131
#   B-Features     0.8435    1.0000    0.9151        97
#    B-HackOrg     0.8172    0.8498    0.8331       426
#       B-Idus     0.9412    0.9320    0.9366       103
#     B-OffAct     0.7059    0.7200    0.7129       100
#        B-Org     0.7526    0.6577    0.7019       111
#       B-Purp     0.8351    0.9878    0.9050        82
#    B-SamFile     0.9048    0.8953    0.9000       191
#    B-SecTeam     0.9461    0.8876    0.9159       178
#       B-Time     0.9080    0.8087    0.8555       183
#       B-Tool     0.7794    0.6909    0.7324       317
#        B-Way     0.8455    0.8532    0.8493       109
#       I-Area     0.7705    0.9792    0.8624        48
#        I-Exp     0.9762    1.0000    0.9880        41
#   I-Features     0.8614    1.0000    0.9255        87
#    I-HackOrg     0.6517    0.8227    0.7273       141
#       I-Idus     0.9000    0.9730    0.9351        37
#     I-OffAct     0.7925    0.6462    0.7119        65
#        I-Org     0.6667    0.7536    0.7075        69
#       I-Purp     0.8667    1.0000    0.9286       130
#    I-SamFile     0.9195    0.8989    0.9091        89
#    I-SecTeam     0.8704    0.7231    0.7899        65
#       I-Time     0.7216    0.8140    0.7650        86
#       I-Tool     0.6852    0.7115    0.6981       156
#        I-Way     0.8087    0.8692    0.8378       107
#            O     0.9776    0.9682    0.9729     14309
#
#     accuracy                         0.9451     17602
#    macro avg     0.8273    0.8644    0.8419     17602
# weighted avg     0.9477    0.9451    0.9457     17602
#
# ------------------------------------------------------------
#
# ==================== Epoch 18/30 ====================
# Starting training phase...
# Training: 100%|██████████| 329/329 [02:27<00:00,  2.24it/s, Loss=0.335]
# Starting validation phase...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.56it/s]
# Entity-level metrics - F1: 0.7872, Precision: 0.7608, Recall: 0.8155
# No significant improvement. Patience: 3/3
# Early stopping triggered after 18 epochs!
# Saving best model...
# Model saved!
# Evaluating on test set...
# Evaluating: 100%|██████████| 42/42 [00:04<00:00,  8.44it/s]
# Entity-level metrics - F1: 0.8471, Precision: 0.8314, Recall: 0.8633
# Entity-Level Test Report:
#               precision    recall  f1-score   support
#
#         Area     0.6973    0.8426    0.7631       216
#          Exp     0.9706    1.0000    0.9851       132
#     Features     0.9508    1.0000    0.9748       116
#      HackOrg     0.7538    0.8130    0.7823       369
#         Idus     0.8905    0.9457    0.9173       129
#       OffAct     0.8478    0.7800    0.8125       150
#          Org     0.7021    0.7226    0.7122       137
#         Purp     0.8394    1.0000    0.9127       115
#      SamFile     0.9364    0.8911    0.9132       248
#      SecTeam     0.8973    0.8618    0.8792       152
#         Time     0.8864    0.9231    0.9043       169
#         Tool     0.7926    0.7524    0.7720       315
#          Way     0.8919    0.9900    0.9384       100
#
#    micro avg     0.8314    0.8633    0.8471      2348
#    macro avg     0.8505    0.8863    0.8667      2348
# weighted avg     0.8344    0.8633    0.8472      2348
#
# Token-Level Test Report:
#               precision    recall  f1-score   support
#
#       B-Area     0.7413    0.8889    0.8084       216
#        B-Exp     0.9706    1.0000    0.9851       132
#   B-Features     0.9667    1.0000    0.9831       116
#    B-HackOrg     0.7933    0.8320    0.8122       369
#       B-Idus     0.8955    0.9449    0.9195       127
#     B-OffAct     0.8881    0.7933    0.8380       150
#        B-Org     0.7704    0.7591    0.7647       137
#       B-Purp     0.8647    1.0000    0.9274       115
#    B-SamFile     0.9576    0.9113    0.9339       248
#    B-SecTeam     0.9655    0.9211    0.9428       152
#       B-Time     0.9357    0.9581    0.9467       167
#       B-Tool     0.8542    0.7810    0.8159       315
#        B-Way     0.9091    1.0000    0.9524       100
#       I-Area     0.7213    0.8462    0.7788        52
#        I-Exp     0.9800    1.0000    0.9899        49
#   I-Features     0.9869    1.0000    0.9934       151
#    I-HackOrg     0.7426    0.7594    0.7509       133
#       I-Idus     0.7917    1.0000    0.8837        38
#     I-OffAct     0.8795    0.8022    0.8391        91
#        I-Org     0.7619    0.7921    0.7767       101
#       I-Purp     0.8333    1.0000    0.9091       145
#    I-SamFile     0.9667    0.9158    0.9405        95
#    I-SecTeam     0.7833    0.8393    0.8103        56
#       I-Time     0.9286    0.9010    0.9146       101
#       I-Tool     0.8311    0.7640    0.7961       161
#        I-Way     0.8725    1.0000    0.9319        89
#            O     0.9831    0.9768    0.9800     14110
#
#     accuracy                         0.9583     17716
#    macro avg     0.8732    0.9032    0.8861     17716
# weighted avg     0.9595    0.9583    0.9586     17716
#
# Test F1 Score: 0.8471
#
# Saving test predictions...
# Test predictions saved to test_predictions.txt
#
# Testing prediction function with example sentence...
#
# Example prediction:
# John -> B-SecTeam
# lives -> O
# in -> O
# New -> B-Org
# York -> O
# and -> O
# works -> O
# for -> O
# Google -> O
# Confusion matrix saved to confusion_matrix.png
#
# ================================================================================
# NAMED ENTITY RECOGNITION MODEL REPORT
# ================================================================================
#
# Model Architecture:
# - SecBERT + BiLSTM (2 layers) + CRF
# - Pretrained model: jackaduma/SecBERT
# - LSTM hidden dimension: 768
# - Dropout rate: 0.1
#
# Training Details:
# - Training set size: 5251 sentences
# - Validation set size: 662 sentences
# - Test set size: 664 sentences
# - Number of epochs: 30
# - Batch size: 16
# - Initial learning rate: 2e-05
# - Weight decay: 0.01
# - Early stopping patience: 3
# - Early stopping delta: 0.001
# - Final training loss: 0.3345
# - Best validation F1: 0.7902
#
# Performance Metrics:
# - Test F1 Score: 0.8471
#
# Entity-Level Test Report:
#               precision    recall  f1-score   support
#
#         Area     0.6973    0.8426    0.7631       216
#          Exp     0.9706    1.0000    0.9851       132
#     Features     0.9508    1.0000    0.9748       116
#      HackOrg     0.7538    0.8130    0.7823       369
#         Idus     0.8905    0.9457    0.9173       129
#       OffAct     0.8478    0.7800    0.8125       150
#          Org     0.7021    0.7226    0.7122       137
#         Purp     0.8394    1.0000    0.9127       115
#      SamFile     0.9364    0.8911    0.9132       248
#      SecTeam     0.8973    0.8618    0.8792       152
#         Time     0.8864    0.9231    0.9043       169
#         Tool     0.7926    0.7524    0.7720       315
#          Way     0.8919    0.9900    0.9384       100
#
#    micro avg     0.8314    0.8633    0.8471      2348
#    macro avg     0.8505    0.8863    0.8667      2348
# weighted avg     0.8344    0.8633    0.8472      2348
#
#
# Bonus Implementation Notes:
# 1. Used SecBERT instead of standard BERT for better performance in security domain
# 2. Implemented BiLSTM with multiple layers for better feature extraction
# 3. Added gradient clipping to prevent exploding gradients
# 4. Used learning rate scheduler to improve convergence
# 5. Added both token-level and entity-level (seqeval) evaluation
# 6. Implemented early stopping to prevent overfitting and reduce training time
#
# ================================================================================
